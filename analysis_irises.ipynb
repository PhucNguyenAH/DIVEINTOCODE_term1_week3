# %% [markdown]
# # Exploratory data analysis Pre-class assignment 1 Analysis of irises
# ## Name: Nguyen Anh Hoang Phuc

# %% [markdown]
# ## Problem 1

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.DataFrame(data.target, columns=['Species'])

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %% [markdown]
# ## Problem 2

# %%
df = pd.concat([X,y], axis=1)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 0          0
# ...

# %% [markdown]
# ## Problem 3

# %%
print("Display the 4th sample from the beginning and see what each feature is like")
print(df.head())
# Out:
# Display the 4th sample from the beginning and see what each feature is like
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None

# %%
print("Output the total number of samples for each label.")
print("Display the mean, standard deviation, and quartiles of the feature values at once.")
print(df.describe())
# Out:
# Output the total number of samples for each label.
# Display the mean, standard deviation, and quartiles of the feature values at once.
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# ...

# %%
print("Check if there is a missing value in the feature quantity.")
print(df.isnull().any())
# Out:
# Check if there is a missing value in the feature quantity.
# sepal length (cm)    False
# sepal width (cm)     False
# petal length (cm)    False
# petal width (cm)     False
# Species              False
# dtype: bool

# %%
print(df.sum())
# Out:
# sepal length (cm)    876.5
# sepal width (cm)     458.6
# petal length (cm)    563.7
# petal width (cm)     179.9
# Species              150.0
# dtype: float64

# %%
print(df.value_counts())
# Out:
# sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  Species
# 5.8                2.7               5.1                1.9               2          2
# 7.9                3.8               6.4                2.0               2          1
# 5.4                3.0               4.5                1.5               1          1
# 5.5                2.4               3.7                1.0               1          1
#                    2.3               4.0                1.3               1          1
#                                                                                     ..
# 6.3                2.5               4.9                1.5               1          1
#                    2.3               4.4                1.3               1          1
# 6.2                3.4               5.4                2.3               2          1
#                    2.9               4.3                1.3               1          1
# ...

# %% [markdown]
# ## Problem 4

# %% [markdown]
# - There are 150 samples with 4 features: sepal length, sepal width, petal length, petal width
# - There are no null values.
# - Each species (setosa, versicolor, virginica) has 50 samples

# %%
print(df["Species"].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %% [markdown]
# # Problem 5

# %%
print("Extract sepal_width, columns in three different ways")
print(df['sepal width (cm)'])
# Out:
# Extract sepal_width, columns in three different ways
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width (cm), Length: 150, dtype: float64

# %%
print(df.iloc[:,1:2])
# Out:
#      sepal width (cm)
# 0                 3.5
# 1                 3.0
# 2                 3.2
# 3                 3.1
# 4                 3.6
# ..                ...
# 145               3.0
# 146               2.5
# 147               3.0
# 148               3.4
# 149               3.0
#
# [150 rows x 1 columns]

# %%
print(df.loc[:,'sepal width (cm)'])
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width (cm), Length: 150, dtype: float64

# %%
print("Extract the 50th to 99th data")
print(df.iloc[50:100])
# Out:
# Extract the 50th to 99th data
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# ...

# %%
print("Extract the50th to 99th data of thepetal_lengthcolumn")
print(df.loc[50:99,['petal length (cm)']])
# Out:
# Extract the50th to 99th data of thepetal_lengthcolumn
#     petal length (cm)
# 50                4.7
# 51                4.5
# 52                4.9
# 53                4.0
# 54                4.6
# 55                4.5
# 56                4.7
# 57                3.3
# 58                4.6
# 59                3.9
# 60                3.5
# 61                4.2
# 62                4.0
# 63                4.7
# 64                3.6
# 65                4.4
# 66                4.5
# 67                4.1
# 68                4.5
# 69                3.9
# 70                4.8
# 71                4.0
# 72                4.9
# 73                4.7
# 74                4.3
# 75                4.4
# 76                4.8
# 77                5.0
# 78                4.5
# 79                3.5
# 80                3.8
# 81                3.7
# 82                3.9
# 83                5.1
# 84                4.5
# 85                4.5
# 86                4.7
# 87                4.4
# ...

# %%
print("Extract data with apetal_width value of 0.2​")
print(df.loc[df['petal width (cm)'] == 0.2, ['petal width (cm)']])
# Out:
# Extract data with apetal_width value of 0.2​
#     petal width (cm)
# 0                0.2
# 1                0.2
# 2                0.2
# 3                0.2
# 4                0.2
# 7                0.2
# 8                0.2
# 10               0.2
# 11               0.2
# 14               0.2
# 20               0.2
# 22               0.2
# 24               0.2
# 25               0.2
# 27               0.2
# 28               0.2
# 29               0.2
# 30               0.2
# 33               0.2
# 34               0.2
# 35               0.2
# 36               0.2
# 38               0.2
# 39               0.2
# 42               0.2
# 46               0.2
# 47               0.2
# 48               0.2
# 49               0.2

# %% [markdown]
# - loc() is label based data selecting method which means that we have to pass the name of the row or column which we want to select. This method includes the last element of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc()
# - iloc() is a indexed based selecting method which means that we have to pass integer index in the method to select specific row/column. This method does not include the last element of the range passed in it unlike loc(). iloc() does not accept the boolean data unlike loc()

# %% [markdown]
# ## Problem 6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

a = df['Species'].value_counts()
species = a.index
count = a.values
colors = ['red', 'yellow', 'green']
plt.pie(count, labels=species,colors = colors, autopct = '%1.1f%%')
plt.xlabel('species')
plt.show()

# %%
print("Select features one by one and visualize the distribution of data for each label using a box plot")
df.boxplot()
# Out:
# Select features one by one and visualize the distribution of data for each label using a box plot
# <AxesSubplot:>

# %%
df.boxplot(['sepal length (cm)'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(['sepal width (cm)'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(['petal length (cm)'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(['petal width (cm)'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(['Species'])
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
print("Select features one by one and visualize the distribution of data for each label using a violin plot")
fig, ax = plt.subplots(figsize =(6, 4)) 
sns.violinplot(ax=ax, y=df["sepal length (cm)"])
# Out:
# Select features one by one and visualize the distribution of data for each label using a violin plot
# <AxesSubplot:ylabel='sepal length (cm)'>

# %%
fig, ax = plt.subplots(figsize =(6, 4))
sns.violinplot(ax=ax, y=df["sepal width (cm)"])
# Out:
# <AxesSubplot:ylabel='sepal width (cm)'>

# %%
fig, ax = plt.subplots(figsize =(6, 4))
sns.violinplot(ax=ax, y=df["petal length (cm)"])
# Out:
# <AxesSubplot:ylabel='petal length (cm)'>

# %%
fig, ax = plt.subplots(figsize =(6, 4))
sns.violinplot(ax=ax, y=df["petal width (cm)"])
# Out:
# <AxesSubplot:ylabel='petal width (cm)'>

# %% [markdown]
# - A violin plot is a method of ploting numeric data. it is similar to box plot, with the addition of a rotated kernel density plot on each side.
# - Violin plot are more informative than a plain box plot.
# - Box plot only shows summary statistics such as mean, median and interquartile ranges. But violin plot shows the full distribution of the data.

# %% [markdown]
# ## Problem 7

# %%
df.plot(kind='scatter', x='sepal length (cm)', y='sepal width (cm)') 
plt.show()

# %%
df.plot(kind='scatter', x='petal length (cm)', y='petal width (cm)') 
plt.show()

# %%
df.plot(kind='scatter', x='sepal length (cm)', y='petal width (cm)') 
plt.show()

# %%
df.plot(kind='scatter', x='sepal width (cm)', y='petal length (cm)') 
plt.show()

# %%
df.plot(kind='scatter', x='sepal length (cm)', y='petal length (cm)') 
plt.show()

# %%
df.plot(kind='scatter', x='sepal width (cm)', y='petal width (cm)') 
plt.show()

# %%
print("Create a scatterplot matrix that displays all combinations of scatterplots at once (1)")
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(15,15))
index = 0
for i in range(3):
    for j in range(i+1,4):
        ax1 = int(index/2)
        ax2 = index % 2
        axes[ax1][ax2].scatter(df[df.columns[i]], df[df.columns[j]], color='blue')
        axes[ax1][ax2].set_xlabel(df.columns[i])
        axes[ax1][ax2].set_ylabel(df.columns[j])
        index = index + 1
# Out:
# Create a scatterplot matrix that displays all combinations of scatterplots at once (1)

# %%
print("Create a correlation coefficient matrix for 4 features")
corr_features = df.iloc[:,:4].corr()
print(corr_features)
# Out:
# Create a correlation coefficient matrix for 4 features
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

print("Make a heat map of the correlation coefficient matrix (1)")
sns.heatmap(corr_features)
plt.show()
# Out:
# Make a heat map of the correlation coefficient matrix (1)

# %% [markdown]
# ## Problem 8

# %% [markdown]
# ### The boxplot
# - The boxplot shows the distribution of the data and spot the outliers effectively.
# - The first thing you might notice in the preceding diagram is a box that contains a horizontal line.
# - The box represents two inner quartiles where 50% of the data resides, and it ranges from the first quartile to the third quartile.
# - The horizontal line represents the median of the data.

# %% [markdown]
# ### The heat map
# - It is a square matrix – each row represents a variable, and all the columns represent the same variables as rows, hence the number of rows = number of columns.
# - Each cell in the grid represents the value of the correlation coefficient between two variables.
# - A value near to 0 (both positive or negative) indicates the absence of any correlation between the two variables, and hence those variables are independent of each other.
# - Each cell in the above matrix is also represented by shades of a color. Here darker shades of the color indicate smaller values while brighter shades correspond to larger values (near to 1).
